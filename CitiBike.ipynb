# %%
import pandas as pd

# %%
df1 = pd.read_csv("resources/bike1.csv")

# %%
df1.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           201  2019-01-01 03:09:09.7110  2019-01-01 03:12:30.8790
# 1           505  2019-01-01 05:18:00.1060  2019-01-01 05:26:25.9050
# 2           756  2019-01-01 10:36:33.3400  2019-01-01 10:49:10.2600
# 3          1575  2019-01-01 12:43:38.6430  2019-01-01 13:09:54.5280
# 4          1566  2019-01-01 12:43:39.6010  2019-01-01 13:09:46.5100
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id    end station name  \
# 0               -74.033459            3214    Essex Light Rail
# ...

# %%
df2 = pd.read_csv("resources/bike2.csv")

# %%
df2.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           142  2019-02-01 15:35:02.0820  2019-02-01 15:37:24.1360
# 1           223  2019-02-01 17:00:46.8900  2019-02-01 17:04:30.5500
# 2           106  2019-02-01 17:08:01.3260  2019-02-01 17:09:47.4400
# 3           370  2019-02-01 17:09:31.2100  2019-02-01 17:15:41.6550
# 4           315  2019-02-01 17:19:53.2490  2019-02-01 17:25:09.1400
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3639       Harborside
# ...

# %%
df3 = pd.read_csv("resources/bike3.csv")

# %%
df3.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           306  2019-03-01 06:47:08.2110  2019-03-01 06:52:14.7150
# 1           123  2019-03-01 07:30:53.0220  2019-03-01 07:32:56.7770
# 2           328  2019-03-01 08:18:30.4030  2019-03-01 08:23:59.0590
# 3            95  2019-03-01 11:04:47.2020  2019-03-01 11:06:22.8130
# 4           169  2019-03-01 11:51:29.4170  2019-03-01 11:54:19.2120
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3267     Morris Canal
# ...

# %%
df4 = pd.read_csv("resources/bike4.csv")

# %%
df4.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           107  2019-04-01 07:48:04.7540  2019-04-01 07:49:52.3590
# 1           493  2019-04-01 12:41:09.6540  2019-04-01 12:49:23.0290
# 2           512  2019-04-01 14:27:07.9400  2019-04-01 14:35:40.9370
# 3           196  2019-04-01 15:07:38.1510  2019-04-01 15:10:54.6260
# 4           463  2019-04-01 16:19:24.6940  2019-04-01 16:27:08.6450
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id  end station name  \
# 0               -74.033459            3184       Paulus Hook
# ...

# %%
df5 = pd.read_csv("resources/bike5.csv")

# %%
df5.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           311  2019-05-01 00:07:36.4670  2019-05-01 00:12:47.6350
# 1           538  2019-05-01 00:08:29.2840  2019-05-01 00:17:27.9410
# 2           178  2019-05-01 00:39:36.4750  2019-05-01 00:42:34.9640
# 3           317  2019-05-01 01:24:28.0220  2019-05-01 01:29:45.5730
# 4           354  2019-05-01 01:54:39.6660  2019-05-01 02:00:34.1750
#
#    start station id start station name  start station latitude  \
# 0              3185          City Hall               40.717733
# 1              3681           Grand St               40.715178
# 2              3638      Washington St               40.724294
# 3              3206            Hilltop               40.731169
# 4              3639         Harborside               40.719252
#
#    start station longitude  end station id end station name  \
# 0               -74.043845            3279      Dixon Mills
# ...

# %%
df6 = pd.read_csv("resources/bike6.csv")

# %%
df7 = pd.read_csv("resources/bike7.csv")

# %%
df8 = pd.read_csv("resources/bike8.csv")

# %%
df9 = pd.read_csv("resources/bike9.csv")

# %%
df10 = pd.read_csv("resources/bike10.csv")

# %%
df11 = pd.read_csv("resources/bike11.csv")

# %%
df12 = pd.read_csv("resources/bike12.csv")

# %%
df_row = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12])

# %%
df_row.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 396422 entries, 0 to 20204
# Data columns (total 15 columns):
# tripduration               396422 non-null int64
# starttime                  396422 non-null object
# stoptime                   396422 non-null object
# start station id           396422 non-null int64
# start station name         396422 non-null object
# start station latitude     396422 non-null float64
# start station longitude    396422 non-null float64
# end station id             396422 non-null int64
# end station name           396422 non-null object
# end station latitude       396422 non-null float64
# end station longitude      396422 non-null float64
# bikeid                     396422 non-null int64
# usertype                   396422 non-null object
# birth year                 396422 non-null int64
# gender                     396422 non-null int64
# dtypes: float64(4), int64(6), object(5)
# memory usage: 48.4+ MB

# %%
df_row.to_excel("citybike.xlsx")
